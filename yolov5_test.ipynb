# %% [markdown]
# # Train YOLO
# This notebook shows how to train a YOLO model on a custom dataset. The model is trained using one of the datasets available in the project

# %%
import torch

# Model
model = torch.hub.load('lib/yolov5', 'custom', path='models/plate_detector.pt', source='local')
# Out:
# YOLOv5  2022-11-28 Python-3.10.8 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 322 layers, 86173414 parameters, 0 gradients, 203.8 GFLOPs
# Adding AutoShape...

# %%
import cv2
from random import sample
from glob import glob

image_paths = glob('data/Dataset_Tradicional/Fig/*.png', recursive=True)

for ip in sample(image_paths,5):
    image = cv2.imread(ip)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    results = model(image, size=480)
    results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>
# <PIL.Image.Image image mode=RGB size=500x500>
# <PIL.Image.Image image mode=RGB size=500x500>
# <PIL.Image.Image image mode=RGB size=400x268>
# <PIL.Image.Image image mode=RGB size=400x225>
