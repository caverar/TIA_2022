# %%
import io
import os

from collections import defaultdict
import tensorflow as tf
import numpy as np
import pandas as pd
import cv2
from keras import backend as K
from keras.layers import Conv2D, Input, BatchNormalization, LeakyReLU, ZeroPadding2D, UpSampling2D, MaxPool2D, Reshape, Activation
from keras.layers import add, concatenate
# from keras.layers.merge import add, concatenate
from keras.models import Model
from keras.utils import get_custom_objects
from tensorflow.python.platform import build_info as tf_build_info
from platform import python_version

IMAGE_SHAPE = (227,227)
IMAGE_SHAPE_C = (227,227,3)
# Out:
# 2022-11-23 20:02:51.212864: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-23 20:02:53.038069: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libdirectml.d6f03b303ac3c4f2eeb8ca631688c9757b361310.so
# 2022-11-23 20:02:53.038142: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libdxcore.so
# 2022-11-23 20:02:53.040536: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libd3d12.so
# 2022-11-23 20:02:53.564713: I tensorflow/c/logging.cc:34] DirectML device enumeration: found 1 compatible adapters.

# %%
class Mish(Activation):

    def __init__(self, activation, **kwargs):
        super(Mish, self).__init__(activation, **kwargs)
        self.__name__ = 'mish'


def mysoftplus(x):

    mask_min = tf.cast((x<-20.0),tf.float32)
    ymin = mask_min*tf.math.exp(x)

    mask_max = tf.cast((x>20.0),tf.float32)
    ymax = mask_max*x

    mask= tf.cast((abs(x)<=20.0),tf.float32)
    y = mask*tf.math.log(tf.math.exp(x) + 1.0)  # type: ignore

    return(ymin+ymax+y)



def mish(x):
    return (x* tf.math.tanh(mysoftplus(x)))




get_custom_objects().update({'mish': Mish(mish)})

def _conv_block(inp, convs, skip=False):
    x = inp
    count = 0

    for conv in convs:
        if count == (len(convs) - 2) and skip:
            skip_connection = x
        count += 1

        if conv['stride'] > 1: x = ZeroPadding2D(((1,0),(1,0)), name='zerop_' + str(conv['layer_idx']))(x)  # peculiar padding as darknet prefer left and top

        x = Conv2D(conv['filter'],
                   conv['kernel'],
                   strides=conv['stride'],
                   padding='valid' if conv['stride'] > 1 else 'same', # peculiar padding as darknet prefer left and top
                   name='convn_' + str(conv['layer_idx']) if conv['bnorm'] else 'conv_' + str(conv['layer_idx']),
                   use_bias=True)(x)

        if conv['bnorm']: x = BatchNormalization(name='BN_' + str(conv['layer_idx']))(x)

        if conv['activ'] == 1: x = LeakyReLU(alpha=0.1, name='leaky_' + str(conv['layer_idx']))(x)
        if conv['activ'] == 2: x = Activation('mish', name='mish_' + str(conv['layer_idx']))(x)

    return add([skip_connection, x],  name='add_' + str(conv['layer_idx']+1)) if skip else x

def make_yolov4_model():

    input_image = Input(shape=IMAGE_SHAPE_C, name='input_0')

    # Layer  0
    x = _conv_block(input_image, [{'filter': 32, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 0}])
    layer_0 = x
    # Layer  1
    x = _conv_block(x, [{'filter': 64, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 2, 'layer_idx': 1}])
    layer_1 = x

    # Layer  2
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 2}])
    layer_2 = x

    # route  1 (layers = -2)
    x = layer_1
    # Layer  3 => 5
    x = _conv_block(x, [{'filter': 64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 4},
                        {'filter': 32, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 5},
                        {'filter': 64, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 6}],
                   skip = True)

    # Layer  8 => 8
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 8}])
    layer_8 = x

    # route  8+2 (layers = -1, -7)
    x = concatenate([layer_8, layer_2], name='concat_9')

    # Layer 10 => 11
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 10},
                        {'filter': 128, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 2, 'layer_idx': 11}])
    layer_11 = x

    # Layer  12
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 12}])
    layer_12 = x

    # route  11 (layers = -2)
    x = layer_11
    # Layer 14 => 16
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 14},
                        {'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 15},
                        {'filter':  64, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 16}],
                   skip = True)

    # Layer 18 => 19
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 18},
                        {'filter':  64, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 19}],
                   skip = True)

    # Layer  21
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 21}])
    layer_21 = x

    # route  21+12 (layers = -1,-10)
    x = concatenate([layer_21, layer_12], name='concat_22')

    # Layer 23 => 24
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 23},
                        {'filter':  256, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 2, 'layer_idx': 24}])
    layer_24 = x

    # Layer  25
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 25}])
    layer_25 = x

    # route  24 (layers = -2)
    x = layer_24

    # Layer 27 => 29
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 27},
                        {'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 28},
                        {'filter':  128, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 29}],
                   skip = True)

    # Layer 31 => 50
    for i in range(7):
        x = _conv_block(x, [{'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 31+(i*3)},
                            {'filter': 128, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 32+(i*3)}],
                       skip = True)

    # Layer  52
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 52}])
    layer_52 = x

    # route  52+25 (layers = -1,-28)
    x = concatenate([layer_52, layer_25],  name='concat_53')

    # Layer 54
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 54}])
    layer_54 = x

    # Layer  55
    x = _conv_block(x, [{'filter':  512, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 2, 'layer_idx': 55}])
    layer_55 = x

    # Layer  56
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 56}])
    layer_56 = x

    # route  55 (layers = -2)
    x = layer_55

    # Layer 58 => 60
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 58},
                        {'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 59},
                        {'filter':  256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 60}],
                   skip = True)

    # Layer 62 => 81
    for i in range(7):
        x = _conv_block(x, [{'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 62+(i*3)},
                            {'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 63+(i*3)}],
                       skip = True)

    # Layer  83
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 83}])
    layer_83 = x

    # route  83+56 (layers = -1,-28)
    x = concatenate([layer_83, layer_56], name='concat_84')

    # Layer 85
    x = _conv_block(x, [{'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 85}])
    layer_85 = x

    # Layer  86
    x = _conv_block(x, [{'filter':  1024, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 2, 'layer_idx': 86}])
    layer_86 = x

    # Layer  87
    x = _conv_block(x, [{'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 87}])
    layer_87 = x

    # route  86 (layers = -2)
    x = layer_86

    # Layer 89 => 92
    x = _conv_block(x, [{'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 89},
                        {'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 90},
                        {'filter':  512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 91}],
                   skip = True)


    # Layer 93 => 100
    for i in range(3):
        x = _conv_block(x, [{'filter': 512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 93+(i*3)},
                            {'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 94+(i*3)}],
                       skip = True)


    # Layer  102 => 102
    x = _conv_block(x, [{'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 102}])
    layer_102 = x

    # route  102+87 (layers = -1,-16)
    x = concatenate([layer_102, layer_87], name='concat_103')

    # Layer 104 => 107
    x = _conv_block(x, [{'filter':  1024, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 2, 'layer_idx': 104},
                        {'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 105},
                        {'filter':  1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 106},
                        {'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 107}])
    layer_107 = x

    # Layer 108
    x =MaxPool2D(pool_size=(5, 5), strides=1, padding='same', name = 'layer_108')(x)
    layer_108 = x

    # route  107 (layers = -2)
    x = layer_107

    # Layer 110
    x =MaxPool2D(pool_size=(9, 9), strides=1, padding='same', name = 'layer_110')(x)
    layer_110 = x

    # route  107 (layers = -4)
    x = layer_107

    # Layer 112
    x =MaxPool2D(pool_size=(13, 13), strides=1, padding='same', name = 'layer_112')(x)
    layer_112 = x

    # route  112+110+108+107 (layers=-1,-3,-5,-6)
    x = concatenate([layer_112, layer_110, layer_108, layer_107], name='concat_113')
    layer_113 = x

    # Layer 114 => 116
    x = _conv_block(x, [{'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 114},
                        {'filter':  1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 115},
                        {'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 116}])
    layer_116 = x

    # Layer 117
    x = _conv_block(x, [{'filter':   256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 117}])
    layer_117 = x
    # Layer 118
    x = UpSampling2D(size=(2, 2), name = 'upsamp_118')(x)
    layer_118 = x

    # route  85 (layers = 85)
    x = layer_85

    # Layer 120
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 120}])
    layer_120 = x

    # route  120+118 (layers = -1, -3)
    x = concatenate([layer_120, layer_118],  name='concat_121')
    layer_121 = x
    # Layer 122 => 126
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 122},
                        {'filter':  512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 123},
                        {'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 124},
                        {'filter':  512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 125},
                        {'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 126}])
    layer_126 = x

    # Layer 127
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 127}])
    layer_127 = x
    # Layer 128
    x = UpSampling2D(size=(2, 2), name = 'upsamp_128')(x)
    layer_128 = x

    # route  54 (layers = 54)
    x = layer_54

    # Layer 130
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ': 1, 'layer_idx': 130}])
    layer_130 = x

    # route  130+128 (layers = -1, -3)
    x = concatenate([layer_130, layer_128],  name='concat_131')
    layer_131 = x
    # Layer 132 => 136
    x = _conv_block(x, [{'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 132},
                        {'filter':  256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 133},
                        {'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 134},
                        {'filter':  256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 135},
                        {'filter':  128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 136}])
    layer_136 = x

    # Layer 137 => 138
    x = _conv_block(x, [{'filter':  256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 137}])
    layer_137 = x
    x = _conv_block(x, [{'filter':  255, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':  0, 'layer_idx': 138}])

    # Layer 139
    yolo_139 = x

    # route  136 (layers = -4)
    x = layer_136

    # Layer 141
    x = _conv_block(x, [{'filter':  256, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 1, 'layer_idx': 141}])
    layer_141 = x

    # route  141+126 (layers = -1, -16)
    x = concatenate([layer_141, layer_126],  name='concat_142')

    # Layer 143 => 147
    x = _conv_block(x, [{'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':   1, 'layer_idx': 143},
                        {'filter':  512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':   1, 'layer_idx': 144},
                        {'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':   1, 'layer_idx': 145},
                        {'filter':  512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':   1, 'layer_idx': 146},
                        {'filter':  256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':   1, 'layer_idx': 147}])
    layer_147 = x

    # Layer 148 => 149
    x = _conv_block(x, [{'filter':  512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':  1, 'layer_idx': 148},
                        {'filter':  255, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':  0, 'layer_idx': 149}])

    # Layer 150
    yolo_150 = x

    # route  147 (layers = -4)
    x = layer_147

    # Layer 152
    x = _conv_block(x, [{'filter':  512, 'kernel': 3, 'stride': 2, 'bnorm': True, 'activ': 1, 'layer_idx': 152}])
    layer_152 = x

    # route  152+166 (layers = -1, -37)
    x = concatenate([layer_152, layer_116],  name='concat_153')


    # Layer 154 => 160
    x = _conv_block(x, [{'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':    1, 'layer_idx': 154},
                        {'filter':  1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':    1, 'layer_idx': 155},
                        {'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':    1, 'layer_idx': 156},
                        {'filter':  1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':    1, 'layer_idx': 157},
                        {'filter':   512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':    1, 'layer_idx': 158},
                        {'filter':  1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'activ':    1, 'layer_idx': 159},
                        {'filter':   255, 'kernel': 1, 'stride': 1, 'bnorm': True, 'activ':    0, 'layer_idx': 160}])


    # Layer 161
    yolo_161 = x

    model = Model(input_image, [yolo_139, yolo_150, yolo_161], name = 'Yolo_v4')

    return model

yolo_model = make_yolov4_model()
yolo_model.summary()
# Out:
# Model: "Yolo_v4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_0 (InputLayer)           [(None, 227, 227, 3  0           []
#                                 )]
#
#  convn_0 (Conv2D)               (None, 227, 227, 32  896         ['input_0[0][0]']
#                                 )
#
#  BN_0 (BatchNormalization)      (None, 227, 227, 32  128         ['convn_0[0][0]']
#                                 )
#
#  mish_0 (Activation)            (None, 227, 227, 32  0           ['BN_0[0][0]']
#                                 )
#
#  zerop_1 (ZeroPadding2D)        (None, 228, 228, 32  0           ['mish_0[0][0]']
#                                 )
#
#  convn_1 (Conv2D)               (None, 113, 113, 64  18496       ['zerop_1[0][0]']
#                                 )
#
#  BN_1 (BatchNormalization)      (None, 113, 113, 64  256         ['convn_1[0][0]']
#                                 )
#
#  mish_1 (Activation)            (None, 113, 113, 64  0           ['BN_1[0][0]']
#                                 )
#
#  convn_4 (Conv2D)               (None, 113, 113, 64  4160        ['mish_1[0][0]']
#                                 )
#
#  BN_4 (BatchNormalization)      (None, 113, 113, 64  256         ['convn_4[0][0]']
#                                 )
#
#  mish_4 (Activation)            (None, 113, 113, 64  0           ['BN_4[0][0]']
#                                 )
#
#  convn_5 (Conv2D)               (None, 113, 113, 32  2080        ['mish_4[0][0]']
#                                 )
#
#  BN_5 (BatchNormalization)      (None, 113, 113, 32  128         ['convn_5[0][0]']
#                                 )
#
#  mish_5 (Activation)            (None, 113, 113, 32  0           ['BN_5[0][0]']
#                                 )
#
#  convn_6 (Conv2D)               (None, 113, 113, 64  18496       ['mish_5[0][0]']
#                                 )
#
#  BN_6 (BatchNormalization)      (None, 113, 113, 64  256         ['convn_6[0][0]']
#                                 )
#
#  mish_6 (Activation)            (None, 113, 113, 64  0           ['BN_6[0][0]']
#                                 )
#
#  add_7 (Add)                    (None, 113, 113, 64  0           ['mish_4[0][0]',
#                                 )                                 'mish_6[0][0]']
#
#  convn_8 (Conv2D)               (None, 113, 113, 64  4160        ['add_7[0][0]']
#                                 )
#
#  convn_2 (Conv2D)               (None, 113, 113, 64  4160        ['mish_1[0][0]']
#                                 )
#
#  BN_8 (BatchNormalization)      (None, 113, 113, 64  256         ['convn_8[0][0]']
#                                 )
#
#  BN_2 (BatchNormalization)      (None, 113, 113, 64  256         ['convn_2[0][0]']
#                                 )
#
#  mish_8 (Activation)            (None, 113, 113, 64  0           ['BN_8[0][0]']
#                                 )
#
#  mish_2 (Activation)            (None, 113, 113, 64  0           ['BN_2[0][0]']
#                                 )
#
#  concat_9 (Concatenate)         (None, 113, 113, 12  0           ['mish_8[0][0]',
#                                 8)                                'mish_2[0][0]']
#
#  convn_10 (Conv2D)              (None, 113, 113, 64  8256        ['concat_9[0][0]']
#                                 )
#
#  BN_10 (BatchNormalization)     (None, 113, 113, 64  256         ['convn_10[0][0]']
#                                 )
#
#  mish_10 (Activation)           (None, 113, 113, 64  0           ['BN_10[0][0]']
#                                 )
#
#  zerop_11 (ZeroPadding2D)       (None, 114, 114, 64  0           ['mish_10[0][0]']
#                                 )
#
#  convn_11 (Conv2D)              (None, 56, 56, 128)  73856       ['zerop_11[0][0]']
#
#  BN_11 (BatchNormalization)     (None, 56, 56, 128)  512         ['convn_11[0][0]']
#
#  mish_11 (Activation)           (None, 56, 56, 128)  0           ['BN_11[0][0]']
#
#  convn_14 (Conv2D)              (None, 56, 56, 64)   8256        ['mish_11[0][0]']
#
#  BN_14 (BatchNormalization)     (None, 56, 56, 64)   256         ['convn_14[0][0]']
#
#  mish_14 (Activation)           (None, 56, 56, 64)   0           ['BN_14[0][0]']
#
#  convn_15 (Conv2D)              (None, 56, 56, 64)   4160        ['mish_14[0][0]']
#
#  BN_15 (BatchNormalization)     (None, 56, 56, 64)   256         ['convn_15[0][0]']
#
#  mish_15 (Activation)           (None, 56, 56, 64)   0           ['BN_15[0][0]']
#
#  convn_16 (Conv2D)              (None, 56, 56, 64)   36928       ['mish_15[0][0]']
#
#  BN_16 (BatchNormalization)     (None, 56, 56, 64)   256         ['convn_16[0][0]']
#
#  mish_16 (Activation)           (None, 56, 56, 64)   0           ['BN_16[0][0]']
#
#  add_17 (Add)                   (None, 56, 56, 64)   0           ['mish_14[0][0]',
#                                                                   'mish_16[0][0]']
#
#  convn_18 (Conv2D)              (None, 56, 56, 64)   4160        ['add_17[0][0]']
#
#  BN_18 (BatchNormalization)     (None, 56, 56, 64)   256         ['convn_18[0][0]']
#
#  mish_18 (Activation)           (None, 56, 56, 64)   0           ['BN_18[0][0]']
#
#  convn_19 (Conv2D)              (None, 56, 56, 64)   36928       ['mish_18[0][0]']
#
#  BN_19 (BatchNormalization)     (None, 56, 56, 64)   256         ['convn_19[0][0]']
#
#  mish_19 (Activation)           (None, 56, 56, 64)   0           ['BN_19[0][0]']
#
#  add_20 (Add)                   (None, 56, 56, 64)   0           ['add_17[0][0]',
#                                                                   'mish_19[0][0]']
#
#  convn_21 (Conv2D)              (None, 56, 56, 64)   4160        ['add_20[0][0]']
#
#  convn_12 (Conv2D)              (None, 56, 56, 64)   8256        ['mish_11[0][0]']
#
#  BN_21 (BatchNormalization)     (None, 56, 56, 64)   256         ['convn_21[0][0]']
#
#  BN_12 (BatchNormalization)     (None, 56, 56, 64)   256         ['convn_12[0][0]']
#
#  mish_21 (Activation)           (None, 56, 56, 64)   0           ['BN_21[0][0]']
#
#  mish_12 (Activation)           (None, 56, 56, 64)   0           ['BN_12[0][0]']
#
#  concat_22 (Concatenate)        (None, 56, 56, 128)  0           ['mish_21[0][0]',
#                                                                   'mish_12[0][0]']
#
#  convn_23 (Conv2D)              (None, 56, 56, 128)  16512       ['concat_22[0][0]']
#
#  BN_23 (BatchNormalization)     (None, 56, 56, 128)  512         ['convn_23[0][0]']
#
#  mish_23 (Activation)           (None, 56, 56, 128)  0           ['BN_23[0][0]']
#
#  zerop_24 (ZeroPadding2D)       (None, 57, 57, 128)  0           ['mish_23[0][0]']
#
#  convn_24 (Conv2D)              (None, 28, 28, 256)  295168      ['zerop_24[0][0]']
#
#  BN_24 (BatchNormalization)     (None, 28, 28, 256)  1024        ['convn_24[0][0]']
#
#  mish_24 (Activation)           (None, 28, 28, 256)  0           ['BN_24[0][0]']
#
#  convn_27 (Conv2D)              (None, 28, 28, 128)  32896       ['mish_24[0][0]']
#
#  BN_27 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_27[0][0]']
#
#  mish_27 (Activation)           (None, 28, 28, 128)  0           ['BN_27[0][0]']
#
#  convn_28 (Conv2D)              (None, 28, 28, 128)  16512       ['mish_27[0][0]']
#
#  BN_28 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_28[0][0]']
#
#  mish_28 (Activation)           (None, 28, 28, 128)  0           ['BN_28[0][0]']
#
#  convn_29 (Conv2D)              (None, 28, 28, 128)  147584      ['mish_28[0][0]']
#
#  BN_29 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_29[0][0]']
#
#  mish_29 (Activation)           (None, 28, 28, 128)  0           ['BN_29[0][0]']
#
#  add_30 (Add)                   (None, 28, 28, 128)  0           ['mish_27[0][0]',
#                                                                   'mish_29[0][0]']
#
#  convn_31 (Conv2D)              (None, 28, 28, 128)  16512       ['add_30[0][0]']
#
#  BN_31 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_31[0][0]']
#
#  mish_31 (Activation)           (None, 28, 28, 128)  0           ['BN_31[0][0]']
#
#  convn_32 (Conv2D)              (None, 28, 28, 128)  147584      ['mish_31[0][0]']
#
#  BN_32 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_32[0][0]']
#
#  mish_32 (Activation)           (None, 28, 28, 128)  0           ['BN_32[0][0]']
#
#  add_33 (Add)                   (None, 28, 28, 128)  0           ['add_30[0][0]',
#                                                                   'mish_32[0][0]']
#
#  convn_34 (Conv2D)              (None, 28, 28, 128)  16512       ['add_33[0][0]']
#
#  BN_34 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_34[0][0]']
#
#  mish_34 (Activation)           (None, 28, 28, 128)  0           ['BN_34[0][0]']
#
#  convn_35 (Conv2D)              (None, 28, 28, 128)  147584      ['mish_34[0][0]']
#
#  BN_35 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_35[0][0]']
#
#  mish_35 (Activation)           (None, 28, 28, 128)  0           ['BN_35[0][0]']
#
#  add_36 (Add)                   (None, 28, 28, 128)  0           ['add_33[0][0]',
#                                                                   'mish_35[0][0]']
#
#  convn_37 (Conv2D)              (None, 28, 28, 128)  16512       ['add_36[0][0]']
#
#  BN_37 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_37[0][0]']
#
#  mish_37 (Activation)           (None, 28, 28, 128)  0           ['BN_37[0][0]']
#
#  convn_38 (Conv2D)              (None, 28, 28, 128)  147584      ['mish_37[0][0]']
#
#  BN_38 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_38[0][0]']
#
#  mish_38 (Activation)           (None, 28, 28, 128)  0           ['BN_38[0][0]']
#
#  add_39 (Add)                   (None, 28, 28, 128)  0           ['add_36[0][0]',
#                                                                   'mish_38[0][0]']
#
#  convn_40 (Conv2D)              (None, 28, 28, 128)  16512       ['add_39[0][0]']
#
#  BN_40 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_40[0][0]']
#
#  mish_40 (Activation)           (None, 28, 28, 128)  0           ['BN_40[0][0]']
#
#  convn_41 (Conv2D)              (None, 28, 28, 128)  147584      ['mish_40[0][0]']
#
#  BN_41 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_41[0][0]']
#
#  mish_41 (Activation)           (None, 28, 28, 128)  0           ['BN_41[0][0]']
#
#  add_42 (Add)                   (None, 28, 28, 128)  0           ['add_39[0][0]',
#                                                                   'mish_41[0][0]']
#
#  convn_43 (Conv2D)              (None, 28, 28, 128)  16512       ['add_42[0][0]']
#
#  BN_43 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_43[0][0]']
#
#  mish_43 (Activation)           (None, 28, 28, 128)  0           ['BN_43[0][0]']
#
#  convn_44 (Conv2D)              (None, 28, 28, 128)  147584      ['mish_43[0][0]']
#
#  BN_44 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_44[0][0]']
#
#  mish_44 (Activation)           (None, 28, 28, 128)  0           ['BN_44[0][0]']
#
#  add_45 (Add)                   (None, 28, 28, 128)  0           ['add_42[0][0]',
#                                                                   'mish_44[0][0]']
#
#  convn_46 (Conv2D)              (None, 28, 28, 128)  16512       ['add_45[0][0]']
#
#  BN_46 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_46[0][0]']
#
#  mish_46 (Activation)           (None, 28, 28, 128)  0           ['BN_46[0][0]']
#
#  convn_47 (Conv2D)              (None, 28, 28, 128)  147584      ['mish_46[0][0]']
#
#  BN_47 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_47[0][0]']
#
#  mish_47 (Activation)           (None, 28, 28, 128)  0           ['BN_47[0][0]']
#
#  add_48 (Add)                   (None, 28, 28, 128)  0           ['add_45[0][0]',
#                                                                   'mish_47[0][0]']
#
#  convn_49 (Conv2D)              (None, 28, 28, 128)  16512       ['add_48[0][0]']
#
#  BN_49 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_49[0][0]']
#
#  mish_49 (Activation)           (None, 28, 28, 128)  0           ['BN_49[0][0]']
#
#  convn_50 (Conv2D)              (None, 28, 28, 128)  147584      ['mish_49[0][0]']
#
#  BN_50 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_50[0][0]']
#
#  mish_50 (Activation)           (None, 28, 28, 128)  0           ['BN_50[0][0]']
#
#  add_51 (Add)                   (None, 28, 28, 128)  0           ['add_48[0][0]',
#                                                                   'mish_50[0][0]']
#
#  convn_52 (Conv2D)              (None, 28, 28, 128)  16512       ['add_51[0][0]']
#
#  convn_25 (Conv2D)              (None, 28, 28, 128)  32896       ['mish_24[0][0]']
#
#  BN_52 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_52[0][0]']
#
#  BN_25 (BatchNormalization)     (None, 28, 28, 128)  512         ['convn_25[0][0]']
#
#  mish_52 (Activation)           (None, 28, 28, 128)  0           ['BN_52[0][0]']
#
#  mish_25 (Activation)           (None, 28, 28, 128)  0           ['BN_25[0][0]']
#
#  concat_53 (Concatenate)        (None, 28, 28, 256)  0           ['mish_52[0][0]',
#                                                                   'mish_25[0][0]']
#
#  convn_54 (Conv2D)              (None, 28, 28, 256)  65792       ['concat_53[0][0]']
#
#  BN_54 (BatchNormalization)     (None, 28, 28, 256)  1024        ['convn_54[0][0]']
#
#  mish_54 (Activation)           (None, 28, 28, 256)  0           ['BN_54[0][0]']
#
#  zerop_55 (ZeroPadding2D)       (None, 29, 29, 256)  0           ['mish_54[0][0]']
#
#  convn_55 (Conv2D)              (None, 14, 14, 512)  1180160     ['zerop_55[0][0]']
#
#  BN_55 (BatchNormalization)     (None, 14, 14, 512)  2048        ['convn_55[0][0]']
#
#  mish_55 (Activation)           (None, 14, 14, 512)  0           ['BN_55[0][0]']
#
#  convn_58 (Conv2D)              (None, 14, 14, 256)  131328      ['mish_55[0][0]']
#
#  BN_58 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_58[0][0]']
#
#  mish_58 (Activation)           (None, 14, 14, 256)  0           ['BN_58[0][0]']
#
#  convn_59 (Conv2D)              (None, 14, 14, 256)  65792       ['mish_58[0][0]']
#
#  BN_59 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_59[0][0]']
#
#  mish_59 (Activation)           (None, 14, 14, 256)  0           ['BN_59[0][0]']
#
#  convn_60 (Conv2D)              (None, 14, 14, 256)  590080      ['mish_59[0][0]']
#
#  BN_60 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_60[0][0]']
#
#  mish_60 (Activation)           (None, 14, 14, 256)  0           ['BN_60[0][0]']
#
#  add_61 (Add)                   (None, 14, 14, 256)  0           ['mish_58[0][0]',
#                                                                   'mish_60[0][0]']
#
#  convn_62 (Conv2D)              (None, 14, 14, 256)  65792       ['add_61[0][0]']
#
#  BN_62 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_62[0][0]']
#
#  mish_62 (Activation)           (None, 14, 14, 256)  0           ['BN_62[0][0]']
#
#  convn_63 (Conv2D)              (None, 14, 14, 256)  590080      ['mish_62[0][0]']
#
#  BN_63 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_63[0][0]']
#
#  mish_63 (Activation)           (None, 14, 14, 256)  0           ['BN_63[0][0]']
#
#  add_64 (Add)                   (None, 14, 14, 256)  0           ['add_61[0][0]',
#                                                                   'mish_63[0][0]']
#
#  convn_65 (Conv2D)              (None, 14, 14, 256)  65792       ['add_64[0][0]']
#
#  BN_65 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_65[0][0]']
#
#  mish_65 (Activation)           (None, 14, 14, 256)  0           ['BN_65[0][0]']
#
#  convn_66 (Conv2D)              (None, 14, 14, 256)  590080      ['mish_65[0][0]']
#
#  BN_66 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_66[0][0]']
#
#  mish_66 (Activation)           (None, 14, 14, 256)  0           ['BN_66[0][0]']
#
#  add_67 (Add)                   (None, 14, 14, 256)  0           ['add_64[0][0]',
#                                                                   'mish_66[0][0]']
#
#  convn_68 (Conv2D)              (None, 14, 14, 256)  65792       ['add_67[0][0]']
#
#  BN_68 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_68[0][0]']
#
#  mish_68 (Activation)           (None, 14, 14, 256)  0           ['BN_68[0][0]']
#
#  convn_69 (Conv2D)              (None, 14, 14, 256)  590080      ['mish_68[0][0]']
#
#  BN_69 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_69[0][0]']
#
#  mish_69 (Activation)           (None, 14, 14, 256)  0           ['BN_69[0][0]']
#
#  add_70 (Add)                   (None, 14, 14, 256)  0           ['add_67[0][0]',
#                                                                   'mish_69[0][0]']
#
#  convn_71 (Conv2D)              (None, 14, 14, 256)  65792       ['add_70[0][0]']
#
#  BN_71 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_71[0][0]']
#
#  mish_71 (Activation)           (None, 14, 14, 256)  0           ['BN_71[0][0]']
#
#  convn_72 (Conv2D)              (None, 14, 14, 256)  590080      ['mish_71[0][0]']
#
#  BN_72 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_72[0][0]']
#
#  mish_72 (Activation)           (None, 14, 14, 256)  0           ['BN_72[0][0]']
#
#  add_73 (Add)                   (None, 14, 14, 256)  0           ['add_70[0][0]',
#                                                                   'mish_72[0][0]']
#
#  convn_74 (Conv2D)              (None, 14, 14, 256)  65792       ['add_73[0][0]']
#
#  BN_74 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_74[0][0]']
#
#  mish_74 (Activation)           (None, 14, 14, 256)  0           ['BN_74[0][0]']
#
#  convn_75 (Conv2D)              (None, 14, 14, 256)  590080      ['mish_74[0][0]']
#
#  BN_75 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_75[0][0]']
#
#  mish_75 (Activation)           (None, 14, 14, 256)  0           ['BN_75[0][0]']
#
#  add_76 (Add)                   (None, 14, 14, 256)  0           ['add_73[0][0]',
#                                                                   'mish_75[0][0]']
#
#  convn_77 (Conv2D)              (None, 14, 14, 256)  65792       ['add_76[0][0]']
#
#  BN_77 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_77[0][0]']
#
#  mish_77 (Activation)           (None, 14, 14, 256)  0           ['BN_77[0][0]']
#
#  convn_78 (Conv2D)              (None, 14, 14, 256)  590080      ['mish_77[0][0]']
#
#  BN_78 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_78[0][0]']
#
#  mish_78 (Activation)           (None, 14, 14, 256)  0           ['BN_78[0][0]']
#
#  add_79 (Add)                   (None, 14, 14, 256)  0           ['add_76[0][0]',
#                                                                   'mish_78[0][0]']
#
#  convn_80 (Conv2D)              (None, 14, 14, 256)  65792       ['add_79[0][0]']
#
#  BN_80 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_80[0][0]']
#
#  mish_80 (Activation)           (None, 14, 14, 256)  0           ['BN_80[0][0]']
#
#  convn_81 (Conv2D)              (None, 14, 14, 256)  590080      ['mish_80[0][0]']
#
#  BN_81 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_81[0][0]']
#
#  mish_81 (Activation)           (None, 14, 14, 256)  0           ['BN_81[0][0]']
#
#  add_82 (Add)                   (None, 14, 14, 256)  0           ['add_79[0][0]',
#                                                                   'mish_81[0][0]']
#
#  convn_83 (Conv2D)              (None, 14, 14, 256)  65792       ['add_82[0][0]']
#
#  convn_56 (Conv2D)              (None, 14, 14, 256)  131328      ['mish_55[0][0]']
#
#  BN_83 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_83[0][0]']
#
#  BN_56 (BatchNormalization)     (None, 14, 14, 256)  1024        ['convn_56[0][0]']
#
#  mish_83 (Activation)           (None, 14, 14, 256)  0           ['BN_83[0][0]']
#
#  mish_56 (Activation)           (None, 14, 14, 256)  0           ['BN_56[0][0]']
#
#  concat_84 (Concatenate)        (None, 14, 14, 512)  0           ['mish_83[0][0]',
#                                                                   'mish_56[0][0]']
#
#  convn_85 (Conv2D)              (None, 14, 14, 512)  262656      ['concat_84[0][0]']
#
#  BN_85 (BatchNormalization)     (None, 14, 14, 512)  2048        ['convn_85[0][0]']
#
#  mish_85 (Activation)           (None, 14, 14, 512)  0           ['BN_85[0][0]']
#
#  zerop_86 (ZeroPadding2D)       (None, 15, 15, 512)  0           ['mish_85[0][0]']
#
#  convn_86 (Conv2D)              (None, 7, 7, 1024)   4719616     ['zerop_86[0][0]']
#
#  BN_86 (BatchNormalization)     (None, 7, 7, 1024)   4096        ['convn_86[0][0]']
#
#  mish_86 (Activation)           (None, 7, 7, 1024)   0           ['BN_86[0][0]']
#
#  convn_89 (Conv2D)              (None, 7, 7, 512)    524800      ['mish_86[0][0]']
#
#  BN_89 (BatchNormalization)     (None, 7, 7, 512)    2048        ['convn_89[0][0]']
#
#  mish_89 (Activation)           (None, 7, 7, 512)    0           ['BN_89[0][0]']
#
#  convn_90 (Conv2D)              (None, 7, 7, 512)    262656      ['mish_89[0][0]']
#
#  BN_90 (BatchNormalization)     (None, 7, 7, 512)    2048        ['convn_90[0][0]']
#
#  mish_90 (Activation)           (None, 7, 7, 512)    0           ['BN_90[0][0]']
#
#  convn_91 (Conv2D)              (None, 7, 7, 512)    2359808     ['mish_90[0][0]']
# ...
#
#  convn_130 (Conv2D)             (None, 28, 28, 128)  32896       ['mish_54[0][0]']
#
#  BN_127 (BatchNormalization)    (None, 14, 14, 128)  512         ['convn_127[0][0]']
#
#  BN_130 (BatchNormalization)    (None, 28, 28, 128)  512         ['convn_130[0][0]']
#
#  leaky_127 (LeakyReLU)          (None, 14, 14, 128)  0           ['BN_127[0][0]']
#
#  leaky_130 (LeakyReLU)          (None, 28, 28, 128)  0           ['BN_130[0][0]']
#
#  upsamp_128 (UpSampling2D)      (None, 28, 28, 128)  0           ['leaky_127[0][0]']
#
#  concat_131 (Concatenate)       (None, 28, 28, 256)  0           ['leaky_130[0][0]',
#                                                                   'upsamp_128[0][0]']
#
#  convn_132 (Conv2D)             (None, 28, 28, 128)  32896       ['concat_131[0][0]']
#
#  BN_132 (BatchNormalization)    (None, 28, 28, 128)  512         ['convn_132[0][0]']
#
#  leaky_132 (LeakyReLU)          (None, 28, 28, 128)  0           ['BN_132[0][0]']
#
#  convn_133 (Conv2D)             (None, 28, 28, 256)  295168      ['leaky_132[0][0]']
#
#  BN_133 (BatchNormalization)    (None, 28, 28, 256)  1024        ['convn_133[0][0]']
#
#  leaky_133 (LeakyReLU)          (None, 28, 28, 256)  0           ['BN_133[0][0]']
#
#  convn_134 (Conv2D)             (None, 28, 28, 128)  32896       ['leaky_133[0][0]']
#
#  BN_134 (BatchNormalization)    (None, 28, 28, 128)  512         ['convn_134[0][0]']
#
#  leaky_134 (LeakyReLU)          (None, 28, 28, 128)  0           ['BN_134[0][0]']
#
#  convn_135 (Conv2D)             (None, 28, 28, 256)  295168      ['leaky_134[0][0]']
#
#  BN_135 (BatchNormalization)    (None, 28, 28, 256)  1024        ['convn_135[0][0]']
#
#  leaky_135 (LeakyReLU)          (None, 28, 28, 256)  0           ['BN_135[0][0]']
#
#  convn_136 (Conv2D)             (None, 28, 28, 128)  32896       ['leaky_135[0][0]']
#
#  BN_136 (BatchNormalization)    (None, 28, 28, 128)  512         ['convn_136[0][0]']
#
#  leaky_136 (LeakyReLU)          (None, 28, 28, 128)  0           ['BN_136[0][0]']
#
#  zerop_141 (ZeroPadding2D)      (None, 29, 29, 128)  0           ['leaky_136[0][0]']
#
#  convn_141 (Conv2D)             (None, 14, 14, 256)  295168      ['zerop_141[0][0]']
#
#  BN_141 (BatchNormalization)    (None, 14, 14, 256)  1024        ['convn_141[0][0]']
#
#  leaky_141 (LeakyReLU)          (None, 14, 14, 256)  0           ['BN_141[0][0]']
#
#  concat_142 (Concatenate)       (None, 14, 14, 512)  0           ['leaky_141[0][0]',
#                                                                   'leaky_126[0][0]']
#
#  convn_143 (Conv2D)             (None, 14, 14, 256)  131328      ['concat_142[0][0]']
#
#  BN_143 (BatchNormalization)    (None, 14, 14, 256)  1024        ['convn_143[0][0]']
#
#  leaky_143 (LeakyReLU)          (None, 14, 14, 256)  0           ['BN_143[0][0]']
#
#  convn_144 (Conv2D)             (None, 14, 14, 512)  1180160     ['leaky_143[0][0]']
#
#  BN_144 (BatchNormalization)    (None, 14, 14, 512)  2048        ['convn_144[0][0]']
#
#  leaky_144 (LeakyReLU)          (None, 14, 14, 512)  0           ['BN_144[0][0]']
#
#  convn_145 (Conv2D)             (None, 14, 14, 256)  131328      ['leaky_144[0][0]']
#
#  BN_145 (BatchNormalization)    (None, 14, 14, 256)  1024        ['convn_145[0][0]']
#
#  leaky_145 (LeakyReLU)          (None, 14, 14, 256)  0           ['BN_145[0][0]']
#
#  convn_146 (Conv2D)             (None, 14, 14, 512)  1180160     ['leaky_145[0][0]']
#
#  BN_146 (BatchNormalization)    (None, 14, 14, 512)  2048        ['convn_146[0][0]']
#
#  leaky_146 (LeakyReLU)          (None, 14, 14, 512)  0           ['BN_146[0][0]']
#
#  convn_147 (Conv2D)             (None, 14, 14, 256)  131328      ['leaky_146[0][0]']
#
#  BN_147 (BatchNormalization)    (None, 14, 14, 256)  1024        ['convn_147[0][0]']
#
#  leaky_147 (LeakyReLU)          (None, 14, 14, 256)  0           ['BN_147[0][0]']
#
#  zerop_152 (ZeroPadding2D)      (None, 15, 15, 256)  0           ['leaky_147[0][0]']
#
#  convn_152 (Conv2D)             (None, 7, 7, 512)    1180160     ['zerop_152[0][0]']
#
#  BN_152 (BatchNormalization)    (None, 7, 7, 512)    2048        ['convn_152[0][0]']
#
#  leaky_152 (LeakyReLU)          (None, 7, 7, 512)    0           ['BN_152[0][0]']
#
#  concat_153 (Concatenate)       (None, 7, 7, 1024)   0           ['leaky_152[0][0]',
#                                                                   'leaky_116[0][0]']
#
#  convn_154 (Conv2D)             (None, 7, 7, 512)    524800      ['concat_153[0][0]']
#
#  BN_154 (BatchNormalization)    (None, 7, 7, 512)    2048        ['convn_154[0][0]']
#
#  leaky_154 (LeakyReLU)          (None, 7, 7, 512)    0           ['BN_154[0][0]']
#
#  convn_155 (Conv2D)             (None, 7, 7, 1024)   4719616     ['leaky_154[0][0]']
#
#  BN_155 (BatchNormalization)    (None, 7, 7, 1024)   4096        ['convn_155[0][0]']
#
#  leaky_155 (LeakyReLU)          (None, 7, 7, 1024)   0           ['BN_155[0][0]']
#
#  convn_156 (Conv2D)             (None, 7, 7, 512)    524800      ['leaky_155[0][0]']
#
#  BN_156 (BatchNormalization)    (None, 7, 7, 512)    2048        ['convn_156[0][0]']
#
#  leaky_156 (LeakyReLU)          (None, 7, 7, 512)    0           ['BN_156[0][0]']
#
#  convn_157 (Conv2D)             (None, 7, 7, 1024)   4719616     ['leaky_156[0][0]']
#
#  BN_157 (BatchNormalization)    (None, 7, 7, 1024)   4096        ['convn_157[0][0]']
#
#  leaky_157 (LeakyReLU)          (None, 7, 7, 1024)   0           ['BN_157[0][0]']
#
#  convn_158 (Conv2D)             (None, 7, 7, 512)    524800      ['leaky_157[0][0]']
#
#  BN_158 (BatchNormalization)    (None, 7, 7, 512)    2048        ['convn_158[0][0]']
#
#  leaky_158 (LeakyReLU)          (None, 7, 7, 512)    0           ['BN_158[0][0]']
#
#  convn_137 (Conv2D)             (None, 28, 28, 256)  295168      ['leaky_136[0][0]']
#
#  convn_148 (Conv2D)             (None, 14, 14, 512)  1180160     ['leaky_147[0][0]']
#
#  convn_159 (Conv2D)             (None, 7, 7, 1024)   4719616     ['leaky_158[0][0]']
#
#  BN_137 (BatchNormalization)    (None, 28, 28, 256)  1024        ['convn_137[0][0]']
#
#  BN_148 (BatchNormalization)    (None, 14, 14, 512)  2048        ['convn_148[0][0]']
#
#  BN_159 (BatchNormalization)    (None, 7, 7, 1024)   4096        ['convn_159[0][0]']
#
#  leaky_137 (LeakyReLU)          (None, 28, 28, 256)  0           ['BN_137[0][0]']
#
#  leaky_148 (LeakyReLU)          (None, 14, 14, 512)  0           ['BN_148[0][0]']
#
#  leaky_159 (LeakyReLU)          (None, 7, 7, 1024)   0           ['BN_159[0][0]']
#
#  convn_138 (Conv2D)             (None, 28, 28, 255)  65535       ['leaky_137[0][0]']
#
#  convn_149 (Conv2D)             (None, 14, 14, 255)  130815      ['leaky_148[0][0]']
#
#  convn_160 (Conv2D)             (None, 7, 7, 255)    261375      ['leaky_159[0][0]']
#
#  BN_138 (BatchNormalization)    (None, 28, 28, 255)  1020        ['convn_138[0][0]']
#
#  BN_149 (BatchNormalization)    (None, 14, 14, 255)  1020        ['convn_149[0][0]']
#
#  BN_160 (BatchNormalization)    (None, 7, 7, 255)    1020        ['convn_160[0][0]']
#
# ==================================================================================================
# Total params: 64,465,617
# Trainable params: 64,397,783
# Non-trainable params: 67,834
# __________________________________________________________________________________________________

# %%
from keras.models import Model
import struct

class WeightReader:
    def __init__(self, weight_file):
        with open(weight_file, 'rb') as w_f:
            major,    = struct.unpack('i', w_f.read(4))
            minor,    = struct.unpack('i', w_f.read(4))
            revision, = struct.unpack('i', w_f.read(4))

            if (major*10 + minor) >= 2 and major < 1000 and minor < 1000:
                print("reading 64 bytes")
                w_f.read(8)
            else:
                print("reading 32 bytes")
                w_f.read(4)

            transpose = (major > 1000) or (minor > 1000)

            binary = w_f.read()

        self.offset = 0
        self.all_weights = np.frombuffer(binary, dtype='float32')

    def read_bytes(self, size):
        self.offset = self.offset + size
        return self.all_weights[self.offset-size:self.offset]

    def load_weights(self, model):
        count = 0
        ncount = 0
        for i in range(161):
            try:

                conv_layer = model.get_layer('convn_' + str(i))
                filter = conv_layer.kernel.shape[-1]
                nweights = np.prod(conv_layer.kernel.shape) # kernel*kernel*c*filter

                print("loading weights of convolution #" + str(i)+ "- nb parameters: "+str(nweights+filter))

                if i  in [138, 149, 160]:
                    print("Special processing for layer "+ str(i))
                    bias  = self.read_bytes(filter) # bias
                    weights = self.read_bytes(nweights) # weights

                else:
                    bias  = self.read_bytes(filter) # bias
                    scale = self.read_bytes(filter) # scale
                    mean  = self.read_bytes(filter) # mean
                    var   = self.read_bytes(filter) # variance
                    weights = self.read_bytes(nweights) # weights

                    bias = bias - scale  * mean / (np.sqrt(var + 0.00001)) #normalize bias

                    weights = np.reshape(weights,(filter,int(nweights/filter)))  #normalize weights
                    A = scale / (np.sqrt(var + 0.00001))
                    A= np.expand_dims(A,axis=0)
                    weights = weights* A.T
                    weights = np.reshape(weights,(nweights))


                weights = weights.reshape(list(reversed(conv_layer.get_weights()[0].shape)))
                weights = weights.transpose([2,3,1,0])

                if len(conv_layer.get_weights()) > 1:
                    a=conv_layer.set_weights([weights, bias])
                else:
                    a=conv_layer.set_weights([weights])

                count = count+1
                ncount = ncount+nweights+filter

            except ValueError:
                print("no convolution #" + str(i))

        print(count, "Conv normalized layers loaded ", ncount, " parameters")

    def reset(self):
        self.offset = 0
# Get and compute the weights
weight_reader = WeightReader('models/yolov4.weights')
weight_reader.load_weights(yolo_model)
# Out:
# reading 64 bytes
# loading weights of convolution #0- nb parameters: 896
# loading weights of convolution #1- nb parameters: 18496
# loading weights of convolution #2- nb parameters: 4160
# no convolution #3
# loading weights of convolution #4- nb parameters: 4160
# loading weights of convolution #5- nb parameters: 2080
# loading weights of convolution #6- nb parameters: 18496
# no convolution #7
# loading weights of convolution #8- nb parameters: 4160
# no convolution #9
# loading weights of convolution #10- nb parameters: 8256
# loading weights of convolution #11- nb parameters: 73856
# loading weights of convolution #12- nb parameters: 8256
# no convolution #13
# loading weights of convolution #14- nb parameters: 8256
# loading weights of convolution #15- nb parameters: 4160
# loading weights of convolution #16- nb parameters: 36928
# no convolution #17
# loading weights of convolution #18- nb parameters: 4160
# loading weights of convolution #19- nb parameters: 36928
# no convolution #20
# loading weights of convolution #21- nb parameters: 4160
# no convolution #22
# loading weights of convolution #23- nb parameters: 16512
# loading weights of convolution #24- nb parameters: 295168
# loading weights of convolution #25- nb parameters: 32896
# no convolution #26
# loading weights of convolution #27- nb parameters: 32896
# loading weights of convolution #28- nb parameters: 16512
# loading weights of convolution #29- nb parameters: 147584
# no convolution #30
# loading weights of convolution #31- nb parameters: 16512
# loading weights of convolution #32- nb parameters: 147584
# no convolution #33
# loading weights of convolution #34- nb parameters: 16512
# loading weights of convolution #35- nb parameters: 147584
# no convolution #36
# loading weights of convolution #37- nb parameters: 16512
# loading weights of convolution #38- nb parameters: 147584
# no convolution #39
# loading weights of convolution #40- nb parameters: 16512
# loading weights of convolution #41- nb parameters: 147584
# no convolution #42
# loading weights of convolution #43- nb parameters: 16512
# loading weights of convolution #44- nb parameters: 147584
# no convolution #45
# loading weights of convolution #46- nb parameters: 16512
# loading weights of convolution #47- nb parameters: 147584
# no convolution #48
# loading weights of convolution #49- nb parameters: 16512
# loading weights of convolution #50- nb parameters: 147584
# no convolution #51
# loading weights of convolution #52- nb parameters: 16512
# no convolution #53
# loading weights of convolution #54- nb parameters: 65792
# loading weights of convolution #55- nb parameters: 1180160
# loading weights of convolution #56- nb parameters: 131328
# no convolution #57
# loading weights of convolution #58- nb parameters: 131328
# loading weights of convolution #59- nb parameters: 65792
# loading weights of convolution #60- nb parameters: 590080
# no convolution #61
# loading weights of convolution #62- nb parameters: 65792
# loading weights of convolution #63- nb parameters: 590080
# no convolution #64
# loading weights of convolution #65- nb parameters: 65792
# loading weights of convolution #66- nb parameters: 590080
# no convolution #67
# loading weights of convolution #68- nb parameters: 65792
# loading weights of convolution #69- nb parameters: 590080
# no convolution #70
# loading weights of convolution #71- nb parameters: 65792
# loading weights of convolution #72- nb parameters: 590080
# no convolution #73
# loading weights of convolution #74- nb parameters: 65792
# loading weights of convolution #75- nb parameters: 590080
# no convolution #76
# loading weights of convolution #77- nb parameters: 65792
# loading weights of convolution #78- nb parameters: 590080
# no convolution #79
# loading weights of convolution #80- nb parameters: 65792
# loading weights of convolution #81- nb parameters: 590080
# no convolution #82
# loading weights of convolution #83- nb parameters: 65792
# no convolution #84
# loading weights of convolution #85- nb parameters: 262656
# loading weights of convolution #86- nb parameters: 4719616
# loading weights of convolution #87- nb parameters: 524800
# no convolution #88
# loading weights of convolution #89- nb parameters: 524800
# loading weights of convolution #90- nb parameters: 262656
# loading weights of convolution #91- nb parameters: 2359808
# no convolution #92
# loading weights of convolution #93- nb parameters: 262656
# loading weights of convolution #94- nb parameters: 2359808
# no convolution #95
# loading weights of convolution #96- nb parameters: 262656
# loading weights of convolution #97- nb parameters: 2359808
# no convolution #98
# loading weights of convolution #99- nb parameters: 262656
# loading weights of convolution #100- nb parameters: 2359808
# no convolution #101
# loading weights of convolution #102- nb parameters: 262656
# no convolution #103
# loading weights of convolution #104- nb parameters: 1049600
# loading weights of convolution #105- nb parameters: 524800
# loading weights of convolution #106- nb parameters: 4719616
# loading weights of convolution #107- nb parameters: 524800
# no convolution #108
# no convolution #109
# no convolution #110
# no convolution #111
# no convolution #112
# no convolution #113
# loading weights of convolution #114- nb parameters: 1049088
# loading weights of convolution #115- nb parameters: 4719616
# loading weights of convolution #116- nb parameters: 524800
# loading weights of convolution #117- nb parameters: 131328
# no convolution #118
# no convolution #119
# loading weights of convolution #120- nb parameters: 131328
# no convolution #121
# loading weights of convolution #122- nb parameters: 131328
# loading weights of convolution #123- nb parameters: 1180160
# loading weights of convolution #124- nb parameters: 131328
# loading weights of convolution #125- nb parameters: 1180160
# loading weights of convolution #126- nb parameters: 131328
# loading weights of convolution #127- nb parameters: 32896
# no convolution #128
# no convolution #129
# loading weights of convolution #130- nb parameters: 32896
# no convolution #131
# loading weights of convolution #132- nb parameters: 32896
# loading weights of convolution #133- nb parameters: 295168
# loading weights of convolution #134- nb parameters: 32896
# loading weights of convolution #135- nb parameters: 295168
# loading weights of convolution #136- nb parameters: 32896
# loading weights of convolution #137- nb parameters: 295168
# loading weights of convolution #138- nb parameters: 65535
# Special processing for layer 138
# no convolution #139
# no convolution #140
# loading weights of convolution #141- nb parameters: 295168
# no convolution #142
# loading weights of convolution #143- nb parameters: 131328
# loading weights of convolution #144- nb parameters: 1180160
# loading weights of convolution #145- nb parameters: 131328
# loading weights of convolution #146- nb parameters: 1180160
# loading weights of convolution #147- nb parameters: 131328
# loading weights of convolution #148- nb parameters: 1180160
# loading weights of convolution #149- nb parameters: 130815
# Special processing for layer 149
# no convolution #150
# no convolution #151
# loading weights of convolution #152- nb parameters: 1180160
# no convolution #153
# loading weights of convolution #154- nb parameters: 524800
# loading weights of convolution #155- nb parameters: 4719616
# loading weights of convolution #156- nb parameters: 524800
# loading weights of convolution #157- nb parameters: 4719616
# loading weights of convolution #158- nb parameters: 524800
# loading weights of convolution #159- nb parameters: 4719616
# loading weights of convolution #160- nb parameters: 261375
# Special processing for layer 160
# 110 Conv normalized layers loaded  64329949  parameters

# %%
# Freeze the backbone

# Fine-tune from this layer onwards
fine_tune_at = "convn_136"

# Freeze all the layers before the `fine_tune_at` layer
train = False
for l in yolo_model.layers:
  if l.name == fine_tune_at:
        train = True
  l.trainable =  train


# Display the trainable indicator
for l in yolo_model.layers:
    print("layer ",l.name, " trainable: ", l.trainable)
# Out:
# layer  input_0  trainable:  False
# layer  convn_0  trainable:  False
# layer  BN_0  trainable:  False
# layer  mish_0  trainable:  False
# layer  zerop_1  trainable:  False
# layer  convn_1  trainable:  False
# layer  BN_1  trainable:  False
# layer  mish_1  trainable:  False
# layer  convn_4  trainable:  False
# layer  BN_4  trainable:  False
# layer  mish_4  trainable:  False
# layer  convn_5  trainable:  False
# layer  BN_5  trainable:  False
# layer  mish_5  trainable:  False
# layer  convn_6  trainable:  False
# layer  BN_6  trainable:  False
# layer  mish_6  trainable:  False
# layer  add_7  trainable:  False
# layer  convn_8  trainable:  False
# layer  convn_2  trainable:  False
# layer  BN_8  trainable:  False
# layer  BN_2  trainable:  False
# layer  mish_8  trainable:  False
# layer  mish_2  trainable:  False
# layer  concat_9  trainable:  False
# layer  convn_10  trainable:  False
# layer  BN_10  trainable:  False
# layer  mish_10  trainable:  False
# layer  zerop_11  trainable:  False
# layer  convn_11  trainable:  False
# layer  BN_11  trainable:  False
# layer  mish_11  trainable:  False
# layer  convn_14  trainable:  False
# layer  BN_14  trainable:  False
# layer  mish_14  trainable:  False
# layer  convn_15  trainable:  False
# layer  BN_15  trainable:  False
# layer  mish_15  trainable:  False
# layer  convn_16  trainable:  False
# layer  BN_16  trainable:  False
# layer  mish_16  trainable:  False
# layer  add_17  trainable:  False
# layer  convn_18  trainable:  False
# layer  BN_18  trainable:  False
# layer  mish_18  trainable:  False
# layer  convn_19  trainable:  False
# layer  BN_19  trainable:  False
# layer  mish_19  trainable:  False
# layer  add_20  trainable:  False
# layer  convn_21  trainable:  False
# layer  convn_12  trainable:  False
# layer  BN_21  trainable:  False
# layer  BN_12  trainable:  False
# layer  mish_21  trainable:  False
# layer  mish_12  trainable:  False
# layer  concat_22  trainable:  False
# layer  convn_23  trainable:  False
# layer  BN_23  trainable:  False
# layer  mish_23  trainable:  False
# layer  zerop_24  trainable:  False
# layer  convn_24  trainable:  False
# layer  BN_24  trainable:  False
# layer  mish_24  trainable:  False
# layer  convn_27  trainable:  False
# layer  BN_27  trainable:  False
# layer  mish_27  trainable:  False
# layer  convn_28  trainable:  False
# layer  BN_28  trainable:  False
# layer  mish_28  trainable:  False
# layer  convn_29  trainable:  False
# layer  BN_29  trainable:  False
# layer  mish_29  trainable:  False
# layer  add_30  trainable:  False
# layer  convn_31  trainable:  False
# layer  BN_31  trainable:  False
# layer  mish_31  trainable:  False
# layer  convn_32  trainable:  False
# layer  BN_32  trainable:  False
# layer  mish_32  trainable:  False
# layer  add_33  trainable:  False
# layer  convn_34  trainable:  False
# layer  BN_34  trainable:  False
# layer  mish_34  trainable:  False
# layer  convn_35  trainable:  False
# layer  BN_35  trainable:  False
# layer  mish_35  trainable:  False
# layer  add_36  trainable:  False
# layer  convn_37  trainable:  False
# layer  BN_37  trainable:  False
# layer  mish_37  trainable:  False
# layer  convn_38  trainable:  False
# layer  BN_38  trainable:  False
# layer  mish_38  trainable:  False
# layer  add_39  trainable:  False
# layer  convn_40  trainable:  False
# layer  BN_40  trainable:  False
# layer  mish_40  trainable:  False
# layer  convn_41  trainable:  False
# layer  BN_41  trainable:  False
# layer  mish_41  trainable:  False
# layer  add_42  trainable:  False
# layer  convn_43  trainable:  False
# layer  BN_43  trainable:  False
# layer  mish_43  trainable:  False
# layer  convn_44  trainable:  False
# layer  BN_44  trainable:  False
# layer  mish_44  trainable:  False
# layer  add_45  trainable:  False
# layer  convn_46  trainable:  False
# layer  BN_46  trainable:  False
# layer  mish_46  trainable:  False
# layer  convn_47  trainable:  False
# layer  BN_47  trainable:  False
# layer  mish_47  trainable:  False
# layer  add_48  trainable:  False
# layer  convn_49  trainable:  False
# layer  BN_49  trainable:  False
# layer  mish_49  trainable:  False
# layer  convn_50  trainable:  False
# layer  BN_50  trainable:  False
# layer  mish_50  trainable:  False
# layer  add_51  trainable:  False
# layer  convn_52  trainable:  False
# layer  convn_25  trainable:  False
# layer  BN_52  trainable:  False
# layer  BN_25  trainable:  False
# layer  mish_52  trainable:  False
# layer  mish_25  trainable:  False
# layer  concat_53  trainable:  False
# layer  convn_54  trainable:  False
# layer  BN_54  trainable:  False
# layer  mish_54  trainable:  False
# layer  zerop_55  trainable:  False
# layer  convn_55  trainable:  False
# layer  BN_55  trainable:  False
# layer  mish_55  trainable:  False
# layer  convn_58  trainable:  False
# layer  BN_58  trainable:  False
# layer  mish_58  trainable:  False
# layer  convn_59  trainable:  False
# layer  BN_59  trainable:  False
# layer  mish_59  trainable:  False
# layer  convn_60  trainable:  False
# layer  BN_60  trainable:  False
# layer  mish_60  trainable:  False
# layer  add_61  trainable:  False
# layer  convn_62  trainable:  False
# layer  BN_62  trainable:  False
# layer  mish_62  trainable:  False
# layer  convn_63  trainable:  False
# layer  BN_63  trainable:  False
# layer  mish_63  trainable:  False
# layer  add_64  trainable:  False
# layer  convn_65  trainable:  False
# layer  BN_65  trainable:  False
# layer  mish_65  trainable:  False
# layer  convn_66  trainable:  False
# layer  BN_66  trainable:  False
# layer  mish_66  trainable:  False
# layer  add_67  trainable:  False
# layer  convn_68  trainable:  False
# layer  BN_68  trainable:  False
# layer  mish_68  trainable:  False
# layer  convn_69  trainable:  False
# layer  BN_69  trainable:  False
# layer  mish_69  trainable:  False
# layer  add_70  trainable:  False
# layer  convn_71  trainable:  False
# layer  BN_71  trainable:  False
# layer  mish_71  trainable:  False
# layer  convn_72  trainable:  False
# layer  BN_72  trainable:  False
# layer  mish_72  trainable:  False
# layer  add_73  trainable:  False
# layer  convn_74  trainable:  False
# layer  BN_74  trainable:  False
# layer  mish_74  trainable:  False
# layer  convn_75  trainable:  False
# layer  BN_75  trainable:  False
# layer  mish_75  trainable:  False
# layer  add_76  trainable:  False
# layer  convn_77  trainable:  False
# layer  BN_77  trainable:  False
# layer  mish_77  trainable:  False
# layer  convn_78  trainable:  False
# layer  BN_78  trainable:  False
# layer  mish_78  trainable:  False
# layer  add_79  trainable:  False
# layer  convn_80  trainable:  False
# layer  BN_80  trainable:  False
# layer  mish_80  trainable:  False
# layer  convn_81  trainable:  False
# layer  BN_81  trainable:  False
# layer  mish_81  trainable:  False
# layer  add_82  trainable:  False
# layer  convn_83  trainable:  False
# layer  convn_56  trainable:  False
# layer  BN_83  trainable:  False
# layer  BN_56  trainable:  False
# layer  mish_83  trainable:  False
# layer  mish_56  trainable:  False
# layer  concat_84  trainable:  False
# layer  convn_85  trainable:  False
# layer  BN_85  trainable:  False
# layer  mish_85  trainable:  False
# layer  zerop_86  trainable:  False
# layer  convn_86  trainable:  False
# layer  BN_86  trainable:  False
# layer  mish_86  trainable:  False
# layer  convn_89  trainable:  False
# layer  BN_89  trainable:  False
# layer  mish_89  trainable:  False
# layer  convn_90  trainable:  False
# layer  BN_90  trainable:  False
# layer  mish_90  trainable:  False
# layer  convn_91  trainable:  False
# layer  BN_91  trainable:  False
# layer  mish_91  trainable:  False
# layer  add_92  trainable:  False
# layer  convn_93  trainable:  False
# layer  BN_93  trainable:  False
# layer  mish_93  trainable:  False
# layer  convn_94  trainable:  False
# layer  BN_94  trainable:  False
# layer  mish_94  trainable:  False
# layer  add_95  trainable:  False
# layer  convn_96  trainable:  False
# layer  BN_96  trainable:  False
# layer  mish_96  trainable:  False
# layer  convn_97  trainable:  False
# layer  BN_97  trainable:  False
# layer  mish_97  trainable:  False
# layer  add_98  trainable:  False
# layer  convn_99  trainable:  False
# layer  BN_99  trainable:  False
# layer  mish_99  trainable:  False
# layer  convn_100  trainable:  False
# layer  BN_100  trainable:  False
# layer  mish_100  trainable:  False
# layer  add_101  trainable:  False
# layer  convn_102  trainable:  False
# layer  convn_87  trainable:  False
# layer  BN_102  trainable:  False
# layer  BN_87  trainable:  False
# layer  mish_102  trainable:  False
# layer  mish_87  trainable:  False
# layer  concat_103  trainable:  False
# layer  convn_104  trainable:  False
# layer  BN_104  trainable:  False
# layer  mish_104  trainable:  False
# layer  convn_105  trainable:  False
# layer  BN_105  trainable:  False
# layer  leaky_105  trainable:  False
# layer  convn_106  trainable:  False
# layer  BN_106  trainable:  False
# layer  leaky_106  trainable:  False
# layer  convn_107  trainable:  False
# layer  BN_107  trainable:  False
# layer  leaky_107  trainable:  False
# layer  layer_112  trainable:  False
# layer  layer_110  trainable:  False
# layer  layer_108  trainable:  False
# layer  concat_113  trainable:  False
# layer  convn_114  trainable:  False
# layer  BN_114  trainable:  False
# layer  leaky_114  trainable:  False
# layer  convn_115  trainable:  False
# layer  BN_115  trainable:  False
# layer  leaky_115  trainable:  False
# layer  convn_116  trainable:  False
# layer  BN_116  trainable:  False
# layer  leaky_116  trainable:  False
# layer  convn_117  trainable:  False
# layer  convn_120  trainable:  False
# layer  BN_117  trainable:  False
# layer  BN_120  trainable:  False
# layer  leaky_117  trainable:  False
# layer  leaky_120  trainable:  False
# layer  upsamp_118  trainable:  False
# layer  concat_121  trainable:  False
# layer  convn_122  trainable:  False
# layer  BN_122  trainable:  False
# layer  leaky_122  trainable:  False
# layer  convn_123  trainable:  False
# layer  BN_123  trainable:  False
# layer  leaky_123  trainable:  False
# layer  convn_124  trainable:  False
# layer  BN_124  trainable:  False
# layer  leaky_124  trainable:  False
# layer  convn_125  trainable:  False
# layer  BN_125  trainable:  False
# layer  leaky_125  trainable:  False
# layer  convn_126  trainable:  False
# layer  BN_126  trainable:  False
# layer  leaky_126  trainable:  False
# layer  convn_127  trainable:  False
# layer  convn_130  trainable:  False
# layer  BN_127  trainable:  False
# layer  BN_130  trainable:  False
# layer  leaky_127  trainable:  False
# layer  leaky_130  trainable:  False
# layer  upsamp_128  trainable:  False
# layer  concat_131  trainable:  False
# layer  convn_132  trainable:  False
# layer  BN_132  trainable:  False
# layer  leaky_132  trainable:  False
# layer  convn_133  trainable:  False
# layer  BN_133  trainable:  False
# layer  leaky_133  trainable:  False
# layer  convn_134  trainable:  False
# layer  BN_134  trainable:  False
# layer  leaky_134  trainable:  False
# layer  convn_135  trainable:  False
# layer  BN_135  trainable:  False
# layer  leaky_135  trainable:  False
# layer  convn_136  trainable:  True
# layer  BN_136  trainable:  True
# layer  leaky_136  trainable:  True
# layer  zerop_141  trainable:  True
# layer  convn_141  trainable:  True
# layer  BN_141  trainable:  True
# layer  leaky_141  trainable:  True
# layer  concat_142  trainable:  True
# layer  convn_143  trainable:  True
# layer  BN_143  trainable:  True
# layer  leaky_143  trainable:  True
# layer  convn_144  trainable:  True
# layer  BN_144  trainable:  True
# layer  leaky_144  trainable:  True
# layer  convn_145  trainable:  True
# layer  BN_145  trainable:  True
# layer  leaky_145  trainable:  True
# layer  convn_146  trainable:  True
# layer  BN_146  trainable:  True
# layer  leaky_146  trainable:  True
# layer  convn_147  trainable:  True
# layer  BN_147  trainable:  True
# layer  leaky_147  trainable:  True
# layer  zerop_152  trainable:  True
# layer  convn_152  trainable:  True
# layer  BN_152  trainable:  True
# layer  leaky_152  trainable:  True
# layer  concat_153  trainable:  True
# layer  convn_154  trainable:  True
# layer  BN_154  trainable:  True
# layer  leaky_154  trainable:  True
# layer  convn_155  trainable:  True
# layer  BN_155  trainable:  True
# layer  leaky_155  trainable:  True
# layer  convn_156  trainable:  True
# layer  BN_156  trainable:  True
# layer  leaky_156  trainable:  True
# layer  convn_157  trainable:  True
# layer  BN_157  trainable:  True
# layer  leaky_157  trainable:  True
# layer  convn_158  trainable:  True
# layer  BN_158  trainable:  True
# layer  leaky_158  trainable:  True
# layer  convn_137  trainable:  True
# layer  convn_148  trainable:  True
# layer  convn_159  trainable:  True
# layer  BN_137  trainable:  True
# layer  BN_148  trainable:  True
# layer  BN_159  trainable:  True
# layer  leaky_137  trainable:  True
# layer  leaky_148  trainable:  True
# layer  leaky_159  trainable:  True
# layer  convn_138  trainable:  True
# layer  convn_149  trainable:  True
# layer  convn_160  trainable:  True
# layer  BN_138  trainable:  True
# layer  BN_149  trainable:  True
# layer  BN_160  trainable:  True

# %%
labels = ["plate"]
NETWORK_W        = IMAGE_SHAPE[0]
NETWORK_H        = IMAGE_SHAPE[1]
NB_BOX           = 3
NB_CLASS         = len(labels)
OBJ_THRESHOLD    = 0.3
NMS_THRESHOLD    = 0.3
grids = [(76,76), (38,38), (19,19)]
anchors = [ [12, 16, 19, 36, 40, 28],[36, 75, 76, 55, 72, 146],[142, 110, 192, 243, 459, 401]]
scales_x_y = [1.2, 1.1, 1.05]
NO_OBJECT_SCALE  = 1.0
OBJECT_SCALE     = 5.0
COORD_SCALE      = 1.0
CLASS_SCALE      = 1.0

BATCH_SIZE       = 2
TRUE_BOX_BUFFER  = 50
def custom_loss(y_true, y_pred):

    grid_h, grid_w = y_pred.shape[1:3]

    if grid_h == grids[0][0]:
        anchor = anchors[0]
    elif grid_h == grids[1][0]:
        anchor = anchors[1]
    else:
        anchor = anchors[2]
    print("anchor",anchor)

    mask_shape = tf.shape(y_true)[:4]

    cell_x = tf.cast((tf.reshape(tf.tile(tf.range(grid_w), [grid_h]), (1, grid_h, grid_w, 1, 1))),dtype=tf.float32)
    cell_y = tf.transpose(cell_x, (0,2,1,3,4))
    cell_grid = tf.tile(tf.concat([cell_x,cell_y], -1), [BATCH_SIZE, 1, 1, NB_BOX, 1])


    ######  prediction
    y_pred = tf.reshape(y_pred, (BATCH_SIZE, grid_h, grid_w, NB_BOX, NB_CLASS+5))
    print ("prediction", y_pred.shape)

    ### adjust x and y
    pred_box_xy = tf.sigmoid(y_pred[..., :2]) # x, y)
    pred_box_xy = pred_box_xy + cell_grid

    ### adjust w and h
    pred_box_wh = tf.exp(y_pred[..., 2:4]) * np.reshape(anchor, [1,1,1,NB_BOX,2]) / np.full((1,1,1,NB_BOX, 2), [NETWORK_W, NETWORK_H])


    ### adjust objectness
    pred_box_obj = tf.sigmoid(y_pred[..., 4])

    ### adjust class probabilities
    pred_box_class = tf.sigmoid(y_pred[..., 5:])


    ######  true
    y_true = tf.reshape(y_true, (BATCH_SIZE, grid_h, grid_w, NB_BOX, NB_CLASS+5))
    print ("true", y_true.shape)

    ### adjust x and y
    true_box_xy = y_true[..., :2] # x, y

    ### adjust w and h
    true_box_wh = y_true[..., 2:4]

    ### adjust objectness
    true_wh_half = true_box_wh / 2.
    true_mins    = true_box_xy - true_wh_half
    true_maxes   = true_box_xy + true_wh_half

    pred_wh_half = pred_box_wh / 2.
    pred_mins    = pred_box_xy - pred_wh_half
    pred_maxes   = pred_box_xy + pred_wh_half

    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)

    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
    pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas + 1e-10
    iou_scores  = tf.truediv(intersect_areas, union_areas)

    true_box_obj = iou_scores * y_true[..., 4]

    ### adjust class probabilities
    true_box_class = tf.argmax(y_true[..., 5:], -1)



    ######  coefficients

    ### coordinate mask: simply the position of the ground truth boxes (the predictors)
    ### is 1 when there is an object in the cell i, else 0.
    coord_mask = tf.zeros(mask_shape)
    coord_mask = tf.expand_dims(y_true[..., 4], axis=-1) * COORD_SCALE

    ### objectness mask: penelize predictors + penalize boxes with low IOU
    # penalize the confidence of the boxes, which have IOU with some ground truth box < 0.6
    for i in range(BATCH_SIZE):
        bd = y_true[i,:,:,:,:4]
        nozero = tf.not_equal(bd, tf.zeros((grid_h, grid_w, NB_BOX, 4)))
        bdd = tf.boolean_mask(bd, nozero)
        s=tf.squeeze(tf.size(bdd)//4)
        c= tf.zeros((50-s,4))
        bdd=tf.reshape(bdd, (s,4))
        bdd = tf.concat([bdd,c],axis=0)
        bdd = tf.expand_dims(bdd,0)
        bdd = tf.expand_dims(bdd,0)
        bdd = tf.expand_dims(bdd,0)
        bdd = tf.expand_dims(bdd,0)
        if (i==0):
            true_boxes =bdd
        else:
            true_boxes = tf.concat([true_boxes,bdd], axis=0)

    true_xy = true_boxes[..., 0:2]
    true_wh = true_boxes[..., 2:4]
    true_wh_half = true_wh / 2.
    true_mins    = true_xy - true_wh_half
    true_maxes   = true_xy + true_wh_half

    pred_xy = tf.expand_dims(pred_box_xy, 4)
    pred_wh = tf.expand_dims(pred_box_wh, 4)

    pred_wh_half = pred_wh / 2.
    pred_mins    = pred_xy - pred_wh_half
    pred_maxes   = pred_xy + pred_wh_half

    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]

    true_areas = true_wh[..., 0] * true_wh[..., 1]
    pred_areas = pred_wh[..., 0] * pred_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)
    best_ious = tf.reduce_max(iou_scores, axis=4)

    obj_mask = tf.zeros(mask_shape)
    obj_mask = tf.cast((best_ious < 0.6),dtype=tf.float32) * (1 - y_true[..., 4]) * NO_OBJECT_SCALE
    obj_mask = obj_mask + y_true[..., 4] * OBJECT_SCALE


    ### class mask: simply the position of the ground truth boxes (the predictors)
    ### is 1 when there is a particular class is predicted, else 0.
    class_mask = tf.zeros(mask_shape)
    class_weights = np.ones(NB_CLASS, dtype='float32')
    class_mask = y_true[..., 4] * tf.gather(class_weights, true_box_class) * CLASS_SCALE

    nb_coord_box = tf.reduce_sum(tf.cast((coord_mask > 0.0),dtype=tf.float32))
    nb_obj_box  = tf.reduce_sum(tf.cast((obj_mask  > 0.0),dtype=tf.float32))
    nb_class_box = tf.reduce_sum(tf.cast((class_mask > 0.0),dtype=tf.float32))

    ### loss
    loss_xy    = tf.reduce_sum(coord_mask * tf.square(true_box_xy - pred_box_xy)) / (nb_coord_box + 1e-6) / 2.
    loss_wh    = tf.reduce_sum(coord_mask * tf.square(tf.sqrt(tf.abs(true_box_wh)) - tf.sqrt(tf.abs(pred_box_wh)))) / (nb_coord_box + 1e-6) / 2.
    loss_obj   = tf.reduce_sum(obj_mask * tf.square(true_box_obj-pred_box_obj)) / (nb_obj_box + 1e-6) / 2.
    loss_class = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=true_box_class, logits=pred_box_class)
    loss_class = tf.reduce_sum(class_mask * loss_class) / (nb_class_box + 1e-6)

    loss = loss_xy + loss_wh + loss_obj + loss_class
    print()
    return loss

# Choose the optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

#optimizer = tf.keras.optimizers.SGD(lr=1e-4, decay=0.0005, momentum=0.9)
#optimizer = tf.keras.optimizers.SGD.RMSprop(lr=1e-4, rho=0.9, epsilon=1e-08, decay=0.0)


# Compile the model using the custom loss function defined above
yolo_model.compile(loss=custom_loss, optimizer=optimizer, metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
class CustomCallback(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        print("Starting train")

    def on_train_end(self, logs=None):
        print("Stop train")
        
    def on_epoch_begin(self, epoch, logs=None):
        print("--Start epoch {}".format(epoch))

    def on_epoch_end(self, epoch, logs=None):
        print("--End epoch {}, the average training loss is {:7.2f}, testing loss is {:7.2f}".format(epoch, logs["loss"], logs["val_loss"]))        
        
    def on_train_batch_begin(self, batch, logs=None):
        print("---Start training batch {}, size {}".format(batch,logs["size"]))
        
    def on_train_batch_end(self, batch, logs=None):
        print("---End training batch {}, total loss is {:7.2f}, loss (76*76) is {:7.2f}, loss (38*38) is {:7.2f}, loss (19*19) is {:7.2f}"
              .format(batch, logs["loss"],logs["BN_138_loss"],logs["BN_149_loss"],logs["BN_160_loss"]))      

    def on_test_begin(self, logs=None):
        print("-Start testing")
        
    def on_test_end(self, logs=None):
        print("-Stop testing")
    
    def on_test_batch_begin(self, batch, logs=None):
        print("---Start testing batch {}, size {}".format(batch,logs["size"]))
        
    def on_test_batch_end(self, batch, logs=None):
        print("---End testing batch {}, total loss is {:7.2f}, loss (76*76) is {:7.2f}, loss (38*38) is {:7.2f}, loss (19*19) is {:7.2f}"
              .format(batch, logs["loss"],logs["BN_138_loss"],logs["BN_149_loss"],logs["BN_160_loss"]))

# %%
# Load csv
plates_data = pd.read_csv("./normalized_data/unique_plates.csv")

# Take a sample of the data
number_of_samples = 830;
plates_data_sample = plates_data.sample(number_of_samples)

# Create arrays with inputs and outputs
plates_data_in = np.ndarray(shape=(number_of_samples, IMAGE_SHAPE[0], IMAGE_SHAPE[1], 3), dtype=np.uint8)
plates_data_out = np.array([plates_data_sample['xmin'],
                            plates_data_sample['ymin'],
                            plates_data_sample['xmax'],
                            plates_data_sample['ymax']]).T
plates_data_out_tag = np.array([plates_data_sample['tag'],]).T


# Load images from paths in csv

for i, path in enumerate(plates_data_sample['img_path']):
    raw_image = cv2.imread(path, cv2.IMREAD_COLOR)
    plates_data_in[i,:,:,:] = cv2.cvtColor(raw_image, cv2.COLOR_BGR2RGB)  # Reorganize channels to RGB instead of BGR

# Normalize inputs
for i in range(len(plates_data_out)):
    plates_data_out_tag[i][0] = plates_data_out_tag[i][0] / 100     # tag
    plates_data_out[i][0] = plates_data_out[i][0] / IMAGE_SHAPE[0]  # xmin
    plates_data_out[i][1] = plates_data_out[i][1] / IMAGE_SHAPE[1]  # ymin
    plates_data_out[i][2] = plates_data_out[i][2] / IMAGE_SHAPE[0]  # xmax
    plates_data_out[i][3] = plates_data_out[i][3] / IMAGE_SHAPE[1]  # ymax


# print first column of plates_data_sample
#plt.imshow(plates_data_in[i])
#plt.show()

# %%
# for layer in yolo_model.layers:
#     print(layer.get_output_at(0).get_shape().as_list())
for layer in yolo_model.layers:
    print(layer.output_shape)
# Out:
# [(None, 227, 227, 3)]
# (None, 227, 227, 32)
# (None, 227, 227, 32)
# (None, 227, 227, 32)
# (None, 228, 228, 32)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 32)
# (None, 113, 113, 32)
# (None, 113, 113, 32)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 128)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 113, 113, 64)
# (None, 114, 114, 64)
# (None, 56, 56, 128)
# (None, 56, 56, 128)
# (None, 56, 56, 128)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 128)
# (None, 56, 56, 128)
# (None, 56, 56, 128)
# (None, 56, 56, 128)
# (None, 57, 57, 128)
# (None, 28, 28, 256)
# (None, 28, 28, 256)
# (None, 28, 28, 256)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 256)
# (None, 28, 28, 256)
# (None, 28, 28, 256)
# (None, 28, 28, 256)
# (None, 29, 29, 256)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 15, 15, 512)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 2048)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 256)
# (None, 14, 14, 256)
# (None, 7, 7, 256)
# (None, 14, 14, 256)
# (None, 7, 7, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 512)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 128)
# (None, 28, 28, 128)
# (None, 14, 14, 128)
# (None, 28, 28, 128)
# (None, 14, 14, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 256)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 256)
# (None, 28, 28, 256)
# (None, 28, 28, 256)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 256)
# (None, 28, 28, 256)
# (None, 28, 28, 256)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 29, 29, 128)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 512)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 512)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 14, 14, 256)
# (None, 15, 15, 256)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 1024)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 1024)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 7, 7, 512)
# (None, 28, 28, 256)
# (None, 14, 14, 512)
# (None, 7, 7, 1024)
# (None, 28, 28, 256)
# (None, 14, 14, 512)
# (None, 7, 7, 1024)
# (None, 28, 28, 256)
# (None, 14, 14, 512)
# (None, 7, 7, 1024)
# (None, 28, 28, 255)
# (None, 14, 14, 255)
# (None, 7, 7, 255)
# (None, 28, 28, 255)
# (None, 14, 14, 255)
# (None, 7, 7, 255)

# %%
import datetime
start = datetime.datetime.now()

EScallback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)

history = yolo_model.fit(x=plates_data_in, y=plates_data_out, validation_split=0.2, epochs= 3,batch_size = BATCH_SIZE, verbose=2, callbacks=[CustomCallback(),EScallback ])

elapsed = datetime.datetime.now()-start
print("elapsed seconds: ",elapsed.seconds)
# Out:
# Starting train
# --Start epoch 0
# Epoch 1/3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [23], line 6
#       2 start = datetime.datetime.now()
#       4 EScallback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
# ----> 6 history = yolo_model.fit(x=plates_data_in, y=plates_data_out, validation_split=0.2, epochs= 3,batch_size = BATCH_SIZE, verbose=2, callbacks=[CustomCallback(),EScallback ])
#       8 elapsed = datetime.datetime.now()-start
#       9 print("elapsed seconds: ",elapsed.seconds)
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# Cell In [17], line 15, in CustomCallback.on_train_batch_begin(self, batch, logs)
#      14 def on_train_batch_begin(self, batch, logs=None):
# ---> 15     print("---Start training batch {}, size {}".format(batch,logs["size"]))
#
# KeyError: 'size'

# %%
# plot learning curves Loss
from matplotlib import pyplot
pyplot.title('Learning Curves Loss')
pyplot.xlabel('Epoch')
pyplot.ylabel('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='val')
pyplot.legend()
pyplot.show()
# plot learning curves Accuracy
from matplotlib import pyplot
pyplot.title('Learning Curves Accuracy')
pyplot.xlabel('Epoch')
pyplot.ylabel('Accuracy')
pyplot.plot(history.history['BN_138_root_mean_squared_error'], label='train output 76*76')
pyplot.plot(history.history['val_BN_138_root_mean_squared_error'], label='val output 76*76')
pyplot.plot(history.history['BN_149_root_mean_squared_error'], label='train output 38*38')
pyplot.plot(history.history['val_BN_149_root_mean_squared_error'], label='val output 38*38')
pyplot.plot(history.history['BN_160_root_mean_squared_error'], label='train output 19*19')
pyplot.plot(history.history['val_BN_160_root_mean_squared_error'], label='val output 19*19')
pyplot.legend()
pyplot.show()

# %%
print("Num Physical GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num Logical GPUs Available: ", len(tf.config.experimental.list_logical_devices('GPU')))
# Out:
# Num Physical GPUs Available:  1
# Num Logical GPUs Available:  1
# 2022-11-23 20:03:00.852908: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-23 20:03:00.854311: I tensorflow/c/logging.cc:34] DirectML: creating device on adapter 0 (AMD Radeon RX 6650 XT)
# 2022-11-23 20:03:00.922816: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-23 20:03:00.922849: W tensorflow/core/common_runtime/pluggable_device/pluggable_device_bfc_allocator.cc:28] Overriding allow_growth setting because force_memory_growth was requested by the device.
# 2022-11-23 20:03:00.922873: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13970 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
