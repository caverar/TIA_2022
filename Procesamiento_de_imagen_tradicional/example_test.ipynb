# %%
import numpy as np
import cv2 #This is openCV
import matplotlib.pyplot as plt 
from plate_zone_detector import detect_plate
from third_test import test_plate_method_3

img = cv2.imread('Fig/000.png', cv2.IMREAD_COLOR)
b, i, m = test_plate_method_3(img)
print(f"Found plate: {b}")
print(f"{m}")
plt.title("Plate Zone")
plt.imshow(cv2.cvtColor(i, cv2.COLOR_BGR2RGB))
plt.show()



#Upload images and save it in gray scale
# img= cv2.imread('Fig/Placa2.jpg', cv2.IMREAD_COLOR)
# b, i, m = detect_plate(img)
# print(f"Found plate: {b}")
# print(f"{m}")
# plt.title("Plate Zone")
# plt.imshow(cv2.cvtColor(i, cv2.COLOR_BGR2RGB))
# plt.show()
# Out:
# Found plate: [ True]
# METHOD 3
# Plate Zone Image
# Height: 26, Width: 93, Area: 2418
# Height of plate is greater than 10: True
# Width of plate is greater than 50: True
# Height and width relation is 27.96. Valid plate: True
# Found contours: 17
# Number of contours is greater than 10: TrueBinary Image...
# White pixels: [1462.] Black pixels: [956.]
# White-Black-Difference is greater than 0: [ True], [506.]
