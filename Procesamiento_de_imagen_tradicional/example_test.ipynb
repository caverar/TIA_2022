# %%
import numpy as np
import cv2 #This is openCV
import matplotlib.pyplot as plt 
from plate_zone_detector import detect_plate

#Upload images and save it in gray scale
img= cv2.imread('Fig/Placa1.jpg', cv2.IMREAD_COLOR)
b, i, m = detect_plate(img)
print(f"Found plate: {b}")
print(f"{m}")
plt.title("Plate Zone")
plt.imshow(cv2.cvtColor(i, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Found plate: [ True]
# Method 1
# Plate Zone Image
# Height: 99, Width: 209, Area: 20691
# Height of plate is greater than 10: True
# Width of plate is greater than 50: True
# Height and width relation is 47.37. Valid plate: True
# Found contours: 35
# Number of contours is greater than 10: TrueBinary Image...
# White pixels: [14638.] Black pixels: [6053.]
# White-Black-Difference is greater than 0: [ True], [8585.]
